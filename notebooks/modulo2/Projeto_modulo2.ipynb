# %% [markdown]
# <a href="https://colab.research.google.com/github/silva-felipe/BootCamp_Alura_DataScience/blob/main/notebooks/modulo2/Projeto_modulo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contextualização - Cobertura Vacinal infantil

# %% [markdown]
# <c><img src='https://www.cortesvillela.com.br/wp-content/uploads/2018/05/O-que-você-precisa-saber-sobre-vacinação-infantil.png'></c>

# %% [markdown]
# **COBERTURA VACINAL**
#
# A cobertura vacinal é o percentual de crianças imunizadas por vacinas específicas, dentro de um espaço geográfico delimitado em um determinado ano.
#
# • Estima o nível de proteção da população infantil contra doenças selecionadas, evitáveis por imunização, mediante o cumprimento do esquema básico de vacinação.
# <b>fonte:</b> *http://www.ripsa.org.br/fichasIDB/pdf/ficha_F.13.pdf*
#
# **VACINAS ANALISADAS**
#
# - <b>BCG</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-bcg*)
#  - Previne contra Tuberculose – principalmente as formas graves, como meningite tuberculosa e tuberculose miliar (espalhada pelo corpo).
#  - É composta pelo bacilo de Calmette-Guérin – origem do nome BCG – obtido pela atenuação (enfraquecimento) de uma das bactérias que causam a tuberculose. Completam sua composição o glutamato de sódio e a solução fisiológica (soro a 0,9%).
#
#   - <b>Indicação:</b>
#
#    - A vacina é indicada de rotina a partir do nascimento até antes de a criança completar 5 anos de idade.
#
# - <b>Rotavírus humano</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-rotavirus*)
#
#  - Previne contra doença diarreica causada por rotavírus.
#  - Vacina oral monovalente (VRH1) contém um tipo de rotavírus vivo “enfraquecido”, além de sacarose, adipatodissódico, meio Eagle modificado Dulbecco (DMEM) e água estéril.
#
#  - Vacina oral atenuada pentavalente (VRH5) é composta por cinco tipos de rotavírus vivos “enfraquecidos”, sacarose, citrato de sódio, fosfato de sódio monobásico monoidratado, hidróxido de sódio, polissorbato 80, meios de cultura e traços de soro fetal bovino.
#
#  - <b>Indicação:</b>
#
#    - Bebês de 6 semanas a 8 meses e 0 dia. A primeira dose deve ser obrigatoriamente aplicada até a idade de 3 meses e 15 dias, e a última dose até os 7 meses e 29 dias.
#
#
#  - <b>Meningocócica B</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-meningococica-b*)
#
#   - Previne contra meningites e infecções generalizadas (doenças meningocócicas) causadas pela bactéria meningococo do tipo B.
#
#   - Trata-se de vacina inativada, portanto, não causa infecção.
#
#   - É composta por quatro componentes (três proteínas subcapsulares e vesículas da membrana externa do meningococo B), além de hidróxido de alumínio, cloreto de sódio, histidina, sacarose e água para injeção.
#
#   - <b>Indicação:</b>
#
#     - Para crianças e adolescentes, conforme recomendações das sociedades brasileiras de Pediatria (SBP) e Imunizações (SBIm).
#     - Para adultos com até 50 anos, dependendo de risco epidemiológico.
#     - Para viajantes com destino às regiões onde há risco aumentado da doença.
#     - Para pessoas de qualquer idade com doenças que aumentem o risco para a doença meningocócica.
#
#
#  - <b>Hepatite B</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-hepatite-b*)
#
#   - Previne contra infecção do fígado (hepatite) causada pelo vírus da hepatite B.
#
#   - Trata-se de vacina inativada, portanto, não tem como causar a doença.
#
#   - É composta por proteína de superfície do vírus da hepatite B purificado, hidróxido de alumínio, cloreto de sódio e água para injeção. Pode conter fosfato de sódio, fosfato de potássio e borato de sódio.
#
#   - A rede pública utiliza a apresentação multidose (mais de uma dose por frasco), que contém timerosal (derivado do mercúrio) como conservante.
#
#   - <b>Indicação:</b>
#
#     - Para pessoas de todas as faixas etárias. Faz parte da rotina de vacinação das crianças, devendo ser aplicada, de preferência, nas primeiras 12-24 horas após o nascimento, para prevenir hepatite crônica – forma que acomete 90% dos bebês contaminados ao nascer.
#
#     - Especialmente indicada para gestantes não vacinadas.
#
#
#  - <b>Pneumocócica</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-triplice-viral-sarampo-caxumba-e-rubeola-scr*)
#
#   - Previne contra doenças causadas por 23 tipos de pneumococos.
#
#   - Trata-se de vacina inativada, portanto, não tem como causar a doença.
#
#   - É composta de partículas purificadas (polissacarídeos) das cápsulas de 23 tipos de Streptococos pneumoniae (pneumococo), cloreto de sódio, água para injeção e fenol.
#
#   - <b>Indicação:</b>
#
#     - Para crianças acima de 2 anos, adolescentes e adultos que tenham algum problema de saúde que aumenta o risco para doença pneumocócica (diabetes, doenças cardíacas e respiratórias graves; sem baço ou com o funcionamento comprometido desse órgão; com problemas de imunidade, entre outras condições).
#     - Para pessoas a partir de 60 anos deve ser aplicada de rotina.
#     - Não é recomendada como rotina para crianças, adolescentes e adultos saudáveis.
#
#   - <b>Novas vacinas penumocócia</b>
#     - Novas fórmulas de vacinas penumocócias foram implantadas no SUS. Matéria que explica como estão os novos imunizantes e suas recomendações. (<b>fontes:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacinas-pneumococicas-conjugadas* , *https://saude.abril.com.br/medicina/mais-uma-vacina-contra-bacteria-causadora-da-pneumonia-chega-ao-sus/#:~:text=O%20Minist%C3%A9rio%20da%20Sa%C3%BAde%20anunciou,v%C3%ADrus%20HIV%20e%20indiv%C3%ADduos%20transplantados.*
#
#
#  - <b>Poliomielite</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacinas-poliomielite*)
#
#   - Previne contra poliomielite (paralisia infantil).
#
#   - Vacina Oral Poliomielite (VOP) – É uma vacina oral atenuada bivalente, ou seja, composta pelos vírus da pólio tipos 1 e 3, vivos, mas “enfraquecidos”. Contém ainda cloreto de magnésio, estreptomicina, eritromicina, polissorbato 80, L-arginina e água destilada.
#
#   - Vacina Inativada Poliomielite (VIP) – Por ser inativada, não tem como causar a doença. É uma vacina trivalente e injetável, composta por partículas dos vírus da pólio tipos 1, 2 e 3. Contém ainda 2-fenoxietanol, polissorbato 80, formaldeído, meio Hanks 199, ácido clorídrico ou hidróxido de sódio. Pode conter traços de neomicina, estreptomicina e polimixina B, utilizados durante a produção.
#
#   - <b>Indicação:</b>
#
#     - Devido à erradicação da poliomielite em diversas regiões do mundo e também para evitar a paralisia que pode ser causada pelo vírus contido na vacina oral (VOP), a Organização Mundial da Saúde (OMS) recomenda que países como o Brasil, de baixo risco para o desenvolvimento da doença, passem a utilizar a vacina inativada (VIP), sempre que possível.
#     - Desde 2016, o Programa Nacional de Imunizações (PNI) adota a vacina VIP nas três primeiras doses do primeiro ano de vida (aos 2, 4 e 6 meses de idade) e a VOP no reforço e campanhas anuais de vacinação.
#     - A Sociedade Brasileira de Imunizações (SBIm) orienta que a VIP seja a vacina de preferência na administração de todas as doses.
#     - A vacina poliomielite é indicada de rotina para todas as crianças menores de 5 anos.
#     - Para viajantes adolescentes e adultos com destino a países onde a doença é endêmica, como o Paquistão e o Afeganistão, ou a locais onde há risco de transmissão e registro de casos de poliomielite causada pelo vírus vacinal.
#
#
#  - <b>Febre Amarela</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-febre-amarela-fa*)
#
#   - Previne contra Febre amarela.
#
#   - No Brasil estão disponíveis duas vacinas: a produzida por Bio-Manguinhos – Fiocruz, utilizada pela rede pública, e a produzida pela Sanofi Pasteur, utilizada pelos serviços privados de vacinação e eventualmente pela rede pública. Ambas são elaboradas a partir de vírus vivo atenuado, cultivado em ovo de galinha. A vacina de Biomanguinhos apresenta em sua formulação gelatina bovina, eritromicina, canamicina, cloridrato de L-histidina, L-alanina, cloreto de sódio e água para injeção. Já a da Sanofi Pasteur contém: lactose, sorbitol, cloridrato de L-histidina, L-alanina e solução salina.
#
#   - As duas têm perfis de segurança e eficácia semelhantes, estimados em mais de 95% para maiores de 2 anos.
#
#   - É importante ressaltar que os estudos para o uso de doses fracionadas, recomendado apenas durante campanhas do Ministério da Saúde, em localidades e períodos bem definidos, foram realizados apenas com a vacina de Bio-Manguinhos. Não há, portanto, autorização para a administração de doses fracionadas da vacina da Sanofi Pasteur.
#
#   - <b>Indicação:</b>
#
#     - Pessoas a partir de 9 meses de idade.
#
#
#  - <b>Tríplice Viral D1 SCR</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-triplice-viral-sarampo-caxumba-e-rubeola-scr*)
#
#   - Previne contra Sarampo, caxumba e rubéola.
#
#   - Trata-se de vacina atenuada, contendo vírus vivos “enfraquecidos” do sarampo, da rubéola e da caxumba; aminoácidos; albumina humana; sulfato de neomicina; sorbitol e gelatina. Contém também traços de proteína do ovo de galinha usado no processo de fabricação da vacina.
#
#   - No Brasil, uma das vacinas utilizadas na rede pública contém traços de lactoalbumina (proteína do leite de vaca).
#
#   - <b>Indicação:</b>
#
#     - Crianças, adolescentes e adultos.
#
#
#  - <b>DTP</b> (<b>fonte:</b> *https://familia.sbim.org.br/vacinas/vacinas-disponiveis/vacina-triplice-bacteriana-acelular-infantil-dtpa*)
#
#   - Previne Difteria, tétano e coqueluche.
#
#   - Trata-se de vacina inativada, portanto, não tem como causar a doença.
#
#   - Contém os toxoides diftérico e tetânico (derivados das toxinas produzidas pelas bactérias causadoras das doenças), e componentes da cápsula da bactéria da coqueluche (Bordetella pertussis), sal de alumínio como adjuvante, fenoxietanol, cloreto de sódio, e água para injeção.
#
#   - <b>Indicações:</b>
#
#     - Crianças com menos de 7 anos de idade. Mesmo as que já tiveram tétano, difteria, doença causada pelo Haemophilus influenzae tipo b (Hib) e/ou coqueluche devem ser imunizadas, uma vez que estas doenças não conferem proteção permanente frente a novas infecções.
#
# **CALENDÁRIO VACINAL**
#
# ![picture](https://raw.githubusercontent.com/silva-felipe/BootCamp_Alura_DataScience/main/dados/projeto_modulo2/Screen%20Shot%202021-06-13%20at%2016.57.32.png)
#
#
# **DADOS**
#
# Os dados para a cobertura vacinal foram retirados do site: *http://tabnet.datasus.gov.br/cgi/tabcgi.exe?pni/cnv/cpniuf.def*
#
# - <b>*Pontos positivos*</b>
#
#  - Os dados já estão com os valores normalizados pelo percentutal de população vacinadas facilitando as análises.
#
# - <b>*Pontos negativos*</b>
#
#  - A base de dados não disponibiliza o valor absoluto da população.
#  - Assim me impossiblita a realização das análises por região. Assim eu deveria acessar os dados para a população alvo das vacinas para cada ano e então poder realizar os cálculos de porcentagem corretamente. Caso eu utilize os valores recebidos através da base de dados eu incorreria em um erro grave de análise estatística.
#
#
#
# **OBJETIVO**
#
# Verificar como a cobertura vacinal se comporta ao longo do período de 2010 a 2019 em diferentes estados.

# %% [markdown]
# # Obtendo dados para a análise e manipulação do df para organiza-lo.

# %% [markdown]
# **Problema na obtenção dos dados e minha solução**

# %% [markdown]
# Como a minha idéia é analisar a cobertura vacinal dentro do período de 2010 a 2019, precisava obter os dados no site da TABNET, porém não existe a possibilidade de fazer a selecão por -> **Coberturas Vacinais por Imuno segundo Unidade da Federação e Ano** <- então escrevi um script para fazer o download da minha pesquisa para a quantidade de anos que eu desejava a partir de 2019 e retrocedendo até a data mais antiga.
#
# O script se encontra em outro notebook que esta no github, para acessar: https://github.com/silva-felipe/BootCamp_Alura_DataScience/blob/main/notebooks/tabnet_automaition.ipynb
#
# Ainda preciso melhorar um pouco mais o script para poder realizar o renomeamento dos arquivos e subir para o github de forma automática, então essa parte eu fiz manualmente.

# %% [markdown]
# **Importando os módulos necessário**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import ticker
import matplotlib.ticker as ticker
import datetime
from datetime import date

# %% [markdown]
# **Baixando os arquivos no mesmo df**

# %%
df = pd.DataFrame()
ano: int = 2010

for x in range(10):
  url = 'https://raw.githubusercontent.com/silva-felipe/BootCamp_Alura_DataScience/main/dados/projeto_modulo2/{}.csv'.format(ano)
  df = df.append(pd.read_csv(url, encoding='ISO-8859-1',sep=';',skiprows=3,skipfooter=19,thousands='.',decimal=','))
  df['ano'] = 'NaN'

  ano += 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %% [markdown]
# **resetando o index**

# %%
df.reset_index(inplace=True)

# %% [markdown]
# **adicionando o ano**

# %%
ano: int = 2010
i = 0
f = 28
for _ in range(10):
  df.iloc[i:f, 12] = '{}'.format(ano)
  i += 28
  f += 28
  ano += 1

# %% [markdown]
# **dropando o index anitgo**

# %%
df.drop('index', axis=1, inplace=True)

# %% [markdown]
# **info do df para ver quais colunas estão completas**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 280 entries, 0 to 279
# Data columns (total 25 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Unidade da Federação                           280 non-null    object
#  1   072 BCG                                        280 non-null    float64
#  2   061 Rotavírus Humano                           280 non-null    float64
#  3   053 Meningococo C                              280 non-null    float64
#  4   073 Hepatite B                                 280 non-null    float64
#  5   012 Pneumocócica                               280 non-null    float64
#  6   074 Poliomielite                               280 non-null    float64
#  7   006 Febre Amarela                              280 non-null    float64
#  8   021 Tríplice Viral  D1                         280 non-null    float64
# ...

# %% [markdown]
# **selecionando somente os dados que constam em todos os anos**

# %%
df = df[df.columns[:12]]
df.head()
# Out:
#   Unidade da Federação  072 BCG  061 Rotavírus Humano  ...  075 DTP  Total   ano
# 0          11 Rondônia   102.79                 84.74  ...   102.64  80.47  2010
# 1              12 Acre   114.23                 66.75  ...    92.41  77.05  2010
# 2          13 Amazonas   115.98                 58.68  ...    94.17  75.70  2010
# 3           14 Roraima   113.21                 71.68  ...    95.49  77.04  2010
# 4              15 Pará   124.65                 66.89  ...   101.35  86.45  2010
#
# [5 rows x 12 columns]

# %% [markdown]
# **retirando os numeros dos estados**

# %% [markdown]
# Para realizar a retirada dos numeros dos estados, utilizei o for loop para verificar o tamanho do texto e se fosse maior que 5 retiraria os numero por meio do slicing, caso contrario deixaria igual.

# %%
uf = []
for x in df['Unidade da Federação']:
  if len(x) > 5:
    uf.append(x[3:])
  else:
    uf.append(x)

# %% [markdown]
# **criando a coluna uf**

# %%
df['uf'] = uf

# %% [markdown]
# **retirando a coluna Unidade da Federação e setando uf como index**

# %%
df.drop(['Unidade da Federação'], axis=1, inplace=True) # dropando a coluna Unidade da Federação
df.set_index('uf', inplace=True) # setando o index como uf
df.head()
# Out:
#           072 BCG  061 Rotavírus Humano  ...  Total   ano
# uf                                       ...
# Rondônia   102.79                 84.74  ...  80.47  2010
# Acre       114.23                 66.75  ...  77.05  2010
# Amazonas   115.98                 58.68  ...  75.70  2010
# Roraima    113.21                 71.68  ...  77.04  2010
# Pará       124.65                 66.89  ...  86.45  2010
#
# [5 rows x 11 columns]

# %% [markdown]
# **retirando os numeros dos nomes das vacinas**

# %%
colunas_nome_vacinas = []
for x in df.columns.to_list():
  if len(x) > 5:
    colunas_nome_vacinas.append(x[4:])
  else:
    colunas_nome_vacinas.append(x)

df.columns = colunas_nome_vacinas

# %%
df.head()
# Out:
#              BCG  Rotavírus Humano  Meningococo C  ...     DTP  Total   ano
# uf                                                 ...
# Rondônia  102.79             84.74           5.35  ...  102.64  80.47  2010
# Acre      114.23             66.75           0.65  ...   92.41  77.05  2010
# Amazonas  115.98             58.68           2.05  ...   94.17  75.70  2010
# Roraima   113.21             71.68           6.00  ...   95.49  77.04  2010
# Pará      124.65             66.89           2.09  ...  101.35  86.45  2010
#
# [5 rows x 11 columns]

# %% [markdown]
# **transformando a coluna ano em um objeto datetime**

# %%
df['ano'] = df['ano'].astype('datetime64')
df['ano'] = df['ano'].dt.year
df.head()
# Out:
#              BCG  Rotavírus Humano  Meningococo C  ...     DTP  Total   ano
# uf                                                 ...
# Rondônia  102.79             84.74           5.35  ...  102.64  80.47  2010
# Acre      114.23             66.75           0.65  ...   92.41  77.05  2010
# Amazonas  115.98             58.68           2.05  ...   94.17  75.70  2010
# Roraima   113.21             71.68           6.00  ...   95.49  77.04  2010
# Pará      124.65             66.89           2.09  ...  101.35  86.45  2010
#
# [5 rows x 11 columns]

# %% [markdown]
# # Funções

# %% [markdown]
# **Função para gerar o df do(s) estado(s) escolhido(s) e gerar o barplot da(s) vacina(s) escolhidas no período de 2010 a 2019**

# %%
def vacina_estado(estado: str):
  df_estado = df.loc[estado] # criando df com total de vacinas
  df_estado.reset_index(inplace=True) # resetando index
  df_estado.drop(['uf','Total'], axis=1, inplace=True) # dropando colunas uf e Total
  df_estado.set_index('ano', inplace=True) # setando ano como index
  return df_estado, estado

# %%
def barplot_cv_estado(DataFrame, vacinas: list):

  estado = DataFrame[1] # recebendo o nome do estado do DataFrame
  if estado == 'Total': # se for Total mudar para Brasil
    estado = 'Brasil'

  DataFrame = DataFrame[0] # recebendo o DataFrame

  colunas_vac = vacinas # lista de vacinas recebida

  plt.figure(figsize=(18,15)) # tamanho da figura

  for i in enumerate(colunas_vac): # for loop para cada vacina passada
    sns.set_style("whitegrid") # configurando o estilo do plot

    plt.subplot(3,3, i[0]+1)

    # configurando a paleta de cores para barra de acordo com seu valor
    pal = sns.color_palette("flare_r", len(DataFrame[i[1]]))
    rank = DataFrame[i[1]].argsort().argsort()

    # criação do plot
    ax = sns.barplot(data=DataFrame, 
                x=DataFrame.index,
                y=i[1],
                palette=np.array(pal[::-1])[rank])
        
    # configurando a rotação do eixo x para 45 graus
    plt.xticks(rotation=45)

    # configurando o limite do eixo y
    plt.ylim(0,140)
    
    # configurando o eixo x
    plt.xlabel('')

    # configurando o grid
    plt.grid(True, color = '0.95', linestyle = '--')

    # Título superior
    plt.suptitle('Cobertura Vacinal - {} de 2010 a 2019'.format(estado).upper(), 
            weight='bold', fontsize=16)
    
    # salvando plot
    plt.savefig('barplot_{}'.format(estado), bbox_inches='tight', pad_inches=0.2)

# %% [markdown]
# **Função para gerar lineplot do(s) estado(s) e da(s) vacina(s) que deseja comparar**

# %%
def plot_linha(estados: list, vacinas_pesquisa: list):
  
  df_linha = pd.DataFrame() # criando um obejto DataFrame

  for x in estados: # for loop para cada estado passado
    df_estado = vacina_estado(x)[0] # utilizando a função 'vacina_estado' que cria o DataFrame para o estado escolhido 
    df_estado['uf'] = vacina_estado(x)[1] # criando a coluna uf no DataFrame
    df_linha = df_linha.append(df_estado) # adicionando o DataFrame do estado escolhido criado no DataFrame principal
  
  vacinas_pesquisa = vacinas_pesquisa # recebendo a lista de vacinas
  vacinas_pesquisa.append('uf') # adicionando o item 'uf' na lista de vacinas para realizar o slicing corretamente depois
  
  df_linha = df_linha[vacinas_pesquisa] # selecionando no DataFrame as vacinas escolhidas
  
  df_linha.reset_index(inplace=True) # resetando o index

  vacinas = list(df_linha.columns.to_list())[1:-1] # selecionando as vacinas no DataFrame para realizar o plot

  plt.figure(figsize=(18,15)) # configurando o tamanho do plot

  for i in enumerate(vacinas): # for loop para as vacinas escolhidas
    sns.set_style("whitegrid") # configurando o estilo do plot

    plt.subplot(3,3,i[0]+1) # numero de subplots

    # criando o plot
    ax = sns.lineplot(data=df_linha, x='ano', y=i[1], 
                      hue='uf', 
                      palette=sns.color_palette("flare_r", len(set(list(df_linha['uf'])))))

    # rotacão dos ticks no eixo x
    plt.xticks(rotation=45)

    # configurando o grid
    plt.grid(True, color = '0.95', linestyle = '--')

    # configurando o label do eixo x
    plt.xlabel('')

    # configurando a quantidade de ticks no eixo x
    plt.locator_params(axis="x", nbins=10)


  # ajeitando a string para exibir título e salvar o arquivo
  s = ''
  for x in estados:
    s = s + '-' + x
  
  # Super título
  plt.suptitle(f'Lineplot Comparativo {s}'.upper(), weight='bold', fontsize=16)


  # salvando o plot
  plt.savefig('plot_linha_compara{}'.format(s), bbox_inches='tight', pad_inches=0.2)

# %% [markdown]
# **Função para gerar o df e plotar o heatmap**

# %%
def df_heatmap(vacina: str):
  heatmap = df.reset_index()
  heatmap = heatmap.pivot('uf','ano', vacina)
  return heatmap, vacina

# %%
def heatmap_plot(DataFrame):

  vacina = DataFrame[1]

  DataFrame = DataFrame[0]

  plt.figure(figsize=(9,7))

  ax = sns.heatmap(DataFrame, cmap="rocket_r", robust=True)
      
  plt.xticks(rotation=45)

  ax.set_xlabel('')

  ax.set_ylabel('')

  plt.title('{}\n'.format(vacina).upper(), weight='bold', fontsize=14)

  plt.savefig('{}'.format(vacina), bbox_inches='tight', pad_inches=0.2)

# %%
def vacina_escolha_heatmap(vacinas: list):
  
  vac = vacinas

  for i in vac:
    heatmap_vac = df_heatmap(i)
    heatmap_plot(heatmap_vac)

# %% [markdown]
# # Barplot do estado de escolha para verificar a cobertura vacinal entre 2010 e 2019 da(s) vacina(s) escolhida(s)

# %% [markdown]
# ## **São Paulo plot**

# %%
cv_am = vacina_estado('São Paulo')
vac = list(cv_am[0].columns.to_list())
barplot_cv_estado(cv_am, vac)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### <b>Observação da cobertura vacinal através do barplot para São Paulo.</b>
#
# Podemos verificar que o estado de São Paulo apresenta uma cobertura vacinal bastante elevada no período de 2010 até 2018. No ano de 2019 podemos observar que a cobertura vacinal no estado caiu para baixo de 60% para todas as vacinas analisadas.
#
# Em 2010 a cobertura vacinal da Meningocócica C e Pneumocócia foi baixa sendo explicado pela Portaria nº 3.318 publicada em 28 de outubro de 2010, a qual ampliou o calendário de
# vacinação da criança com as vacinas meningocócica
# C conjugada (meningo C) e pneumocócica 10
# valente (pneumo 10). (<b>fonte:</b> *http://portalarquivos2.saude.gov.br/images/pdf/2015/outubro/14/besvs-pni-v46-n30.pdf*)
#
# A única vacina que apresenta um perfil diferente é a vacina para a Febre Amarela, que historicamente apresenta uma baixa cobertura vacinal no estado, pois o estado não é considera região endemica para a doença. Porém desde Setembro de 2017, a Secretaria Municipal de Saúde tem realizado a vacinação da população em áreas de risco de transmissão da febre amarela, no município de São Paulo e ampliada, gradativamente, de acordo com a situação epidemiológica. (<b>fonte:</b> *https://www.prefeitura.sp.gov.br/cidade/secretarias/saude/vigilancia_em_saude/doencas_e_agravos/index.php?p=243611#:~:text=A%20partir%20de%2019%2F03,o%20Munic%C3%ADpio%20de%20S%C3%A3o%20Paulo.*)
#
# Devido ao fatos verificados, podemos perceber o reflexo disso no gráfico, onde a porcentagem da cobertura vacinal para febre amarela no estado de São Paulo aumento nos anos de 2017, 2018 e com uma pequena queda em relação ao ano anterior o ano de 2019 fechou com uma cobertura de cerca de 40%.

# %% [markdown]
# ## **Amazonas plot**

# %%
cv_am = vacina_estado('Amazonas')
vacinas = list(cv_am[0].columns.to_list())
barplot_cv_estado(cv_am, vacinas)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# ### <b>Observação da cobertura vacinal através do barplot para Amazonas.</b>
#
# As vacinas analisadas apresentam uma cobertura vacinal alta ao longo do período estudado com exceção para o Rotavírus Humano, que apresenta uma média de 70%. Outros dados que chamam a atenção é a baixa cobertura para Meningococo e Pneumocócia no ano de 2010.
#
# Explicado pela Portaria nº 3.318 publicada em 28 de outubro de 2010, a qual ampliou o calendário de
# vacinação da criança com as vacinas meningocócica
# C conjugada (meningo C) e pneumocócica 10
# valente (pneumo 10). (<b>fonte:</b> *http://portalarquivos2.saude.gov.br/images/pdf/2015/outubro/14/besvs-pni-v46-n30.pdf*)
#
# Assim como no estado de São Paulo o estado do Amazonas apresenta uma cobertura vacinal para todas as vacinas analisadas abaixo de 60% no ano de 2019.

# %% [markdown]
# # Lineplot da cobertura vacinal para vacina(s) e estado(s)

# %%
estados = ['São Paulo','Amazonas']
vacinas_pesquisa = df.columns.to_list()[:-2]
plot_linha(estados=estados, vacinas_pesquisa=vacinas_pesquisa)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %% [markdown]
# ## Análise comparativa da cobertura vacinal entre os estados de São Paulo e Amazonas
#
# Verificando os lineplots, podemos fazer algumas comparações da cobertura vacinal entre os dois estados.
# Primeiramente, o gráfico que mais chama atenção é para o de Febre Amarela, como explicado anteriormente São Paulo não é considerado uma região endemica para a doença, porém com o surgimento de alguns casos no ano de 2017 a cobertura vacinal foi aumentada no estado. Contudo no estado do Amazonas que é considerado uma região com alta incidência da doença a cobertura é historicamene alta.
#
# Outro gráfico que chama atenção é a cobertura para o Rotavírus Humano que apresenta uma cobertura vacinal abaixo de 90% no estado do Amazonas, onde no ano de 2015 atingiu o seu maior número de cobertura, porém após essa data o valor decreceu novamente e ficou abaixo de 60% assim como no estado de São Paulo.
#
# Os outros gráficos apresentam um perfil parecido.

# %% [markdown]
# # Heatmap da cobertura vacinal no período de 2010 a 2019 para a vacinha escolhida

# %%
# vacinas = df.columns.to_list()[:-1]
vacinas = ['Total']
vacina_escolha_heatmap(vacinas=vacinas)

# %% [markdown]
# ## Heatmap para verificar o comportamento da cobertura vacinal
#
# Observando o gráfico de heatmap, podemos verificar claramente que nacionalmente o ano de 2019 foi o pior ano para a cobertura vacinal no país. E o ano de 2011 foi o melhor ano.

# %% [markdown]
# # Conclusão

# %% [markdown]
# ## Baixa cobertura vacinal recentemente
#
# O mundo ainda não sofria com as consequências de uma pandemia global que nos assola, portanto é uma conclusão difícil de se chegar. Porém existe o movimento antivax que talves ajude a explicar tal decréssimo na cobertura vacinal.
#
# Em 2019 o movimento antivacinação foi incluído pela Organização Mundial de Saúde (OMS) em seu relatório sobre os dez maiores riscos à saúde global. De acordo com a Organização, os movimentos antivacina são tão perigosos quanto os vírus que aparecem nesta lista porque ameaçam reverter o progresso alcançado no combate a doenças evitáveis por vacinação, como o sarampo e a poliomielite. <b>Maiores informações:</b> (*https://www.sbmt.org.br/portal/anti-vaccine-movement-is-one-of-the-ten-threats-to-global-health/*)
#
# No contexto global Brasil apresentava uma alta cobertura vacinal historicamente, porém é observavel a queda na cobertura, abaixo deixo links para artigos que ajudam a explicar as observações realizadas nesse projeto:
#
# link 1: *https://www.conass.org.br/consensus/queda-da-imunizacao-brasil/*
#
# link 2: *https://sbim.org.br/noticias/1359-coberturas-vacinais-no-brasil-sao-baixas-e-heterogeneas-mostram-informacoes-do-pni*
#
# link 3: *https://agenciabrasil.ebc.com.br/saude/noticia/2020-10/em-queda-ha-5-anos-coberturas-vacinais-preocupam-ministerio-da-saude*
#
# link 4: *https://portal.fiocruz.br/sites/portal.fiocruz.br/files/documentos/revistaconsensus_25_a_queda_da_imunizacao.pdf*

# %% [markdown]
# # **Teste**

# %%
# !pip install geopandas
# Out:
# ...
#      |████████████████████████████████| 1.0MB 11.1MB/s
# ...
#      |████████████████████████████████| 6.6MB 39.9MB/s
# ...
#      |████████████████████████████████| 15.4MB 274kB/s
# ...

# %%
import geopandas as gpd

# %%
br_mapa = gpd.read_file('/content/BR_UF_2020.shp')
br_mapa.head()
# Out:
#   CD_UF     NM_UF  ... NM_REGIAO                                           geometry
# 0    11  Rondônia  ...     Norte  POLYGON ((-65.38150 -10.42907, -65.38013 -10.4...
# 1    12      Acre  ...     Norte  POLYGON ((-71.07772 -9.82774, -71.07817 -9.828...
# 2    13  Amazonas  ...     Norte  POLYGON ((-69.83766 -3.68659, -69.82555 -3.620...
# 3    14   Roraima  ...     Norte  POLYGON ((-63.96008 2.47313, -63.96041 2.47416...
# 4    15      Pará  ...     Norte  MULTIPOLYGON (((-51.43248 -0.47334, -51.42949 ...
#
# [5 rows x 5 columns]

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(13, 10))
ax1 = br_mapa.plot(ax=ax1)
plt.show()

# %%
df[df['ano'] == 2019]['Febre Amarela']
# Out:
# uf
# Rondônia               52.74
# Acre                   44.01
# Amazonas               49.10
# Roraima                44.06
# Pará                   38.04
# Amapá                  42.27
# Tocantins              53.07
# Maranhão               43.97
# Piauí                  47.81
# Ceará                   0.43
# Rio Grande do Norte     0.41
# Paraíba                 0.75
# Pernambuco              0.70
# Alagoas                 1.96
# Sergipe                 0.93
# Bahia                  41.14
# Minas Gerais           58.64
# Espírito Santo         46.25
# Rio de Janeiro         26.46
# São Paulo              45.08
# Paraná                 56.64
# Santa Catarina         56.79
# Rio Grande do Sul      42.64
# Mato Grosso do Sul     56.34
# Mato Grosso            49.27
# Goiás                  51.15
# Distrito Federal       55.20
# Total                  39.91
# Name: Febre Amarela, dtype: float64

# %%
f_a = df[df['ano'] == 2019]['Febre Amarela']
f_a
# Out:
# uf
# Rondônia               52.74
# Acre                   44.01
# Amazonas               49.10
# Roraima                44.06
# Pará                   38.04
# Amapá                  42.27
# Tocantins              53.07
# Maranhão               43.97
# Piauí                  47.81
# Ceará                   0.43
# Rio Grande do Norte     0.41
# Paraíba                 0.75
# Pernambuco              0.70
# Alagoas                 1.96
# Sergipe                 0.93
# Bahia                  41.14
# Minas Gerais           58.64
# Espírito Santo         46.25
# Rio de Janeiro         26.46
# São Paulo              45.08
# Paraná                 56.64
# Santa Catarina         56.79
# Rio Grande do Sul      42.64
# Mato Grosso do Sul     56.34
# Mato Grosso            49.27
# Goiás                  51.15
# Distrito Federal       55.20
# Total                  39.91
# Name: Febre Amarela, dtype: float64

# %%
br_mapa = br_mapa.join(f_a, on='NM_UF')

# %%
br_mapa
# Out:
#    CD_UF  ... Febre Amarela
# 0     11  ...         52.74
# 1     12  ...         44.01
# 2     13  ...         49.10
# 3     14  ...         44.06
# 4     15  ...         38.04
# 5     16  ...         42.27
# 6     17  ...         53.07
# 7     21  ...         43.97
# 8     22  ...         47.81
# 9     23  ...          0.43
# 10    24  ...          0.41
# 11    25  ...          0.75
# 12    26  ...          0.70
# 13    27  ...          1.96
# 14    28  ...          0.93
# 15    29  ...         41.14
# 16    31  ...         58.64
# 17    32  ...         46.25
# 18    33  ...         26.46
# 19    35  ...         45.08
# 20    41  ...         56.64
# 21    42  ...         56.79
# 22    43  ...         42.64
# 23    50  ...         56.34
# 24    51  ...         49.27
# 25    52  ...         51.15
# 26    53  ...         55.20
#
# [27 rows x 6 columns]

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(13, 10))
vmin, vmax = 0,100
ax1 = br_mapa.plot(column='Febre Amarela', 
                   legend = True, 
                   linewidth=0.2, 
                   cmap=plt.cm.Wistia, 
                  #  legend_kwds={"label":"Coberuta vacinal", "orientation":"vertical"}, 
                   ax=ax1,
                   vmin=vmin, 
                   vmax=vmax)
sns.set_style('whitegrid')
plt.grid(False)
ax1.tick_params()
plt.show()

# %%
def mapa_heatmap(ano: int, vacina: str):
  br_mapa = gpd.read_file('/content/BR_UF_2020.shp')
  br_heatmap = df[df['ano'] == ano]['{}'.format(vacina)]
  br_mapa = br_mapa.join(br_heatmap, on='NM_UF')
  fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(13, 10))
  vmin, vmax = 0,100
  ax1 = br_mapa.plot(column='{}'.format(vacina), 
                    legend = True, 
                    linewidth=0.2, 
                    cmap=plt.cm.Wistia, 
                    #  legend_kwds={"label":"Coberuta vacinal", "orientation":"vertical"}, 
                    ax=ax1,
                    vmin=vmin, 
                    vmax=vmax)
  sns.set_style('whitegrid')
  plt.grid(False)
  ax1.tick_params()
  plt.title('{} - {}'.format(vacina, ano))
  plt.savefig('br_vc_heatmap_{}_{}'.format(vacina, ano))
  plt.show()

# %%
df.columns
# Out:
# Index(['BCG', 'Rotavírus Humano', 'Meningococo C', 'Hepatite B',
#        'Pneumocócica', 'Poliomielite', 'Febre Amarela', 'Tríplice Viral  D1',
#        'DTP', 'Total', 'ano'],
#       dtype='object')

# %%
mapa_heatmap(2015, 'Rotavírus Humano')

# %%
# !pip install schedule

# %%
import schedule

# %%
schedule.run_pending()

def gif_br_heatmap():
  serie_tempo = range(2010, 2020)
  for t in serie_tempo:
    # if t == 2019:
    mapa_heatmap(t, 'Rotavírus Humano')

schedule.every(3).seconds.do(gif_br_heatmap)
# Out:
# Every 3 seconds do gif_br_heatmap() (last run: [never], next run: 2021-06-14 12:50:12)
